# %%
import os
import shutil
import yaml
from PIL import Image

# Загрузка конфигурации из YAML-файла
def load_yaml_config(yaml_path):
    with open(yaml_path, 'r') as file:
        config = yaml.safe_load(file)
    return config

# Загрузка конфигурации
yaml_path = '/home/jovyan/work/yolo_train/sort.yaml'  # Укажите путь к вашему YAML-файлу
config = load_yaml_config(yaml_path)

# Получение базового пути и путей для обучения
base_path = config['path']
train_image_paths = [os.path.join(base_path, path) for path in config['train_images']]
train_ann_paths = [os.path.join(base_path, path) for path in config['train_annotations']]

# Функция letterbox для ресайза изображения с сохранением пропорций
def letterbox(image, target_size=(640, 640)):
    width, height = image.size
    scale = min(target_size[0] / width, target_size[1] / height)
    new_width = int(width * scale)
    new_height = int(height * scale)
    resized_image = image.resize((new_width, new_height), Image.BILINEAR)
    new_image = Image.new("RGB", target_size, (0, 0, 0))
    new_image.paste(resized_image, ((target_size[0] - new_width) // 2, (target_size[1] - new_height) // 2))
    return new_image

# Функция для вычисления площади bounding box
def calculate_area(x_center, y_center, width, height, img_width, img_height):
    abs_width = width * img_width
    abs_height = height * img_height
    return abs_width * abs_height

# Пути к новой папке only_guns
only_guns_dir = 'only_guns'
images_train_dir = os.path.join(only_guns_dir, 'images', 'train')
labels_dir = os.path.join(only_guns_dir, 'labels')

# Создание новых папок
os.makedirs(images_train_dir, exist_ok=True)
os.makedirs(labels_dir, exist_ok=True)

# Обработка всех путей для обучения
for images_source_dir, labels_source_dir in zip(train_image_paths, train_ann_paths):
    # Получение списка всех изображений и меток
    images = sorted(os.listdir(images_source_dir))
    labels = sorted(os.listdir(labels_source_dir))

    # Убедимся, что количество изображений и меток совпадает
    if len(images) != len(labels):
        print(f"Предупреждение: количество изображений и меток не совпадает в {images_source_dir}")
        continue  # Пропускаем эту папку, если количество файлов не совпадает

    # Проходим по всем изображениям и меткам
    for img_name, lbl_name in zip(images, labels):
        # Полные пути к файлам
        img_path = os.path.join(images_source_dir, img_name)
        lbl_path = os.path.join(labels_source_dir, lbl_name)

        # Пытаемся открыть изображение
        try:
            image = Image.open(img_path)
            img_width, img_height = image.size
        except Exception as e:
            print(f"Ошибка при открытии изображения {img_path}: {e}")
            continue  # Пропускаем это изображение

        # Пытаемся открыть файл с метками
        try:
            with open(lbl_path, 'r') as f:
                lines = f.readlines()
        except Exception as e:
            print(f"Ошибка при открытии файла меток {lbl_path}: {e}")
            continue  # Пропускаем этот файл меток

        # Проверяем, есть ли bounding box с площадью больше 30000
        has_large_box = False
        for line in lines:
            # Убираем пробелы и проверяем, что строка не пустая
            line = line.strip()
            if not line:
                continue  # Пропускаем пустые строки

            # Парсим метку (class_id, x_center, y_center, width, height)
            try:
                class_id, x_center, y_center, width, height = map(float, line.split())
            except ValueError as e:
                print(f"Ошибка при разборе строки в файле {lbl_name}: {line}. Ошибка: {e}")
                continue  # Пропускаем некорректные строки

            # Вычисляем площадь bounding box
            area = calculate_area(x_center, y_center, width, height, img_width, img_height)
            if area > 30000:
                has_large_box = True
                break

        # Если найден bounding box с площадью больше 30000
        if has_large_box:
            # Ресайзим изображение с помощью letterbox
            resized_image = letterbox(image)

            # Сохраняем исходное изображение в папку only_guns/images/train
            original_image_path = os.path.join(images_train_dir, img_name)
            try:
                image.save(original_image_path)
            except Exception as e:
                print(f"Ошибка при сохранении изображения {original_image_path}: {e}")
                continue  # Пропускаем это изображение

            # Сохраняем метки в папку only_guns/labels
            new_lbl_path = os.path.join(labels_dir, lbl_name)
            try:
                shutil.copy(lbl_path, new_lbl_path)
            except Exception as e:
                print(f"Ошибка при копировании меток {lbl_path}: {e}")
                continue  # Пропускаем этот файл меток

            # Сохраняем ресайзнутое изображение (опционально, если нужно)
            resized_image_path = os.path.join(images_train_dir, f"resized_{img_name}")
            try:
                resized_image.save(resized_image_path)
            except Exception as e:
                print(f"Ошибка при сохранении ресайзнутого изображения {resized_image_path}: {e}")

print("Обработка завершена!")
# Out:
# Предупреждение: количество изображений и меток не совпадает в /home/jovyan/work/yolo_train/dataset/films/images/train
# Ошибка при открытии изображения /home/jovyan/work/yolo_train/dataset/mixed/images/train/.ipynb_checkpoints: [Errno 21] Is a directory: '/home/jovyan/work/yolo_train/dataset/mixed/images/train/.ipynb_checkpoints'
# Обработка завершена!

# %%
import os

# Пути к папкам, которые нужно очистить
images_dir = 'only_guns/images/train'  # Папка с изображениями
labels_dir = 'only_guns/labels'        # Папка с метками

# Функция для удаления файлов, начинающихся с "resized_"
def remove_resized_files(directory):
    # Получаем список всех файлов в папке
    files = os.listdir(directory)
    
    # Проходим по каждому файлу
    for file_name in files:
        # Если файл начинается с "resized_", удаляем его
        if file_name.startswith("resized_"):
            file_path = os.path.join(directory, file_name)
            try:
                os.remove(file_path)
                print(f"Удален файл: {file_path}")
            except Exception as e:
                print(f"Ошибка при удалении файла {file_path}: {e}")

# Очищаем папку с изображениями
print("Очистка папки с изображениями...")
remove_resized_files(images_dir)

# Очищаем папку с метками
print("Очистка папки с метками...")
remove_resized_files(labels_dir)

print("Очистка завершена!")
# Out:
# Очистка папки с изображениями...
# Удален файл: only_guns/images/train/resized_00000782.jpg
# Удален файл: only_guns/images/train/resized_armas (2723).jpg
# Удален файл: only_guns/images/train/resized_1011133950_65.jpg
# Удален файл: only_guns/images/train/resized_armas (2750).jpg
# Удален файл: only_guns/images/train/resized_ArminiusC.jpg
# Удален файл: only_guns/images/train/resized_armas (2736).jpg
# Удален файл: only_guns/images/train/resized_armas (2761).jpg
# Удален файл: only_guns/images/train/resized_armas (2825).jpg
# Удален файл: only_guns/images/train/resized_armas (2720).jpg
# Удален файл: only_guns/images/train/resized_1011133951_264.jpg
# Удален файл: only_guns/images/train/resized_00000942.jpg
# Удален файл: only_guns/images/train/resized_SIG-Sauer_P229_E_2.jpg
# Удален файл: only_guns/images/train/resized_armas (2743).jpg
# Удален файл: only_guns/images/train/resized_1851USMarshall.jpg
# Удален файл: only_guns/images/train/resized_armas (2709).jpg
# Удален файл: only_guns/images/train/resized_1011133950_180.jpg
# Удален файл: only_guns/images/train/resized_armas (2740).jpg
# Удален файл: only_guns/images/train/resized_armas (2738).jpg
# Удален файл: only_guns/images/train/resized_1011133951_205.jpg
# Удален файл: only_guns/images/train/resized_armas (2746).jpg
# Удален файл: only_guns/images/train/resized_1011133951_103.jpg
# Удален файл: only_guns/images/train/resized_armas (2732).jpg
# Удален файл: only_guns/images/train/resized_HK_P30L.jpg
# Удален файл: only_guns/images/train/resized_Intratec_Cat_9.jpg
# Удален файл: only_guns/images/train/resized_armas (2701).jpg
# Удален файл: only_guns/images/train/resized_armas (2770).jpg
# Удален файл: only_guns/images/train/resized_1011133951_263.jpg
# Удален файл: only_guns/images/train/resized_armas (2777).jpg
# Удален файл: only_guns/images/train/resized_armas (2951).jpg
# Удален файл: only_guns/images/train/resized_1011133951_309.jpg
# Удален файл: only_guns/images/train/resized_P226r-dak-large.jpg
# Удален файл: only_guns/images/train/resized_1011133951_149.jpg
# Удален файл: only_guns/images/train/resized_1011133951_181.jpg
# Удален файл: only_guns/images/train/resized_Arcus_98.jpg
# Удален файл: only_guns/images/train/resized_Maxsell_Beretta_85_Replica.jpg
# Удален файл: only_guns/images/train/resized_armas (2727).jpg
# Удален файл: only_guns/images/train/resized_00000533.jpg
# Удален файл: only_guns/images/train/resized_1011133951_8.jpg
# Удален файл: only_guns/images/train/resized_00000543.jpg
# Удален файл: only_guns/images/train/resized_Intratec_TEC-_22.jpg
# Удален файл: only_guns/images/train/resized_1011133951_35.jpg
# Удален файл: only_guns/images/train/resized_armas (2718).jpg
# Удален файл: only_guns/images/train/resized_00000311.jpg
# Удален файл: only_guns/images/train/resized_1011133951_155.jpg
# Удален файл: only_guns/images/train/resized_armas (2715).jpg
# Удален файл: only_guns/images/train/resized_1011133951_286.jpg
# Удален файл: only_guns/images/train/resized_armas (2733).jpg
# Удален файл: only_guns/images/train/resized_1011133951_236.jpg
# Удален файл: only_guns/images/train/resized_LiliputPistol.jpg
# Удален файл: only_guns/images/train/resized_armas (2742).jpg
# Удален файл: only_guns/images/train/resized_armas (2710).jpg
# Удален файл: only_guns/images/train/resized_1011133951_17.jpg
# Удален файл: only_guns/images/train/resized_8mm_sig_sauer_prop.jpg
# Удален файл: only_guns/images/train/resized_1011133951_210.jpg
# Удален файл: only_guns/images/train/resized_1011133951_59.jpg
# Удален файл: only_guns/images/train/resized_00000284.jpg
# Удален файл: only_guns/images/train/resized_1011133951_62.jpg
# Удален файл: only_guns/images/train/resized_EKOL_Spec_Silver.jpg
# Удален файл: only_guns/images/train/resized_1011133950_100.jpg
# Удален файл: only_guns/images/train/resized_armas (2877).jpg
# Удален файл: only_guns/images/train/resized_Ng_pistol_beretta92_SN.jpg
# Удален файл: only_guns/images/train/resized_LorcinL_380.jpg
# Удален файл: only_guns/images/train/resized_Bulldog_Hammerless.jpg
# Удален файл: only_guns/images/train/resized_armas (2726).jpg
# Удален файл: only_guns/images/train/resized_00000656.jpg
# Удален файл: only_guns/images/train/resized_1011133951_222.jpg
# Удален файл: only_guns/images/train/resized_armas (2758).jpg
# Удален файл: only_guns/images/train/resized_armas (2729).jpg
# Удален файл: only_guns/images/train/resized_1011133951_307.jpg
# Удален файл: only_guns/images/train/resized_armas (2773).jpg
# Удален файл: only_guns/images/train/resized_armas (2713).jpg
# Удален файл: only_guns/images/train/resized_armas (2712).jpg
# Удален файл: only_guns/images/train/resized_Brixia_92.jpg
# Удален файл: only_guns/images/train/resized_Em-Ge_Model_5.jpg
# Удален файл: only_guns/images/train/resized_Sauer38H.jpg
# Удален файл: only_guns/images/train/resized_armas (2774).jpg
# Удален файл: only_guns/images/train/resized_armas (2707).jpg
# Удален файл: only_guns/images/train/resized_Taurus_911.jpg
# Удален файл: only_guns/images/train/resized_Tec-38Derringer.jpg
# Удален файл: only_guns/images/train/resized_1011133951_285.jpg
# Удален файл: only_guns/images/train/resized_Beretta92oldest.jpg
# Удален файл: only_guns/images/train/resized_armas (2739).jpg
# Удален файл: only_guns/images/train/resized_00000098.jpg
# Удален файл: only_guns/images/train/resized_1011133951_252.jpg
# Удален файл: only_guns/images/train/resized_HK_P_30.jpg
# Удален файл: only_guns/images/train/resized_00000790.jpg
# Удален файл: only_guns/images/train/resized_1011133951_259.jpg
# Удален файл: only_guns/images/train/resized_1011133951_173.jpg
# Удален файл: only_guns/images/train/resized_1011133951_95.jpg
# Удален файл: only_guns/images/train/resized_armas (2760).jpg
# Удален файл: only_guns/images/train/resized_Llama-Model-II.jpg
# Удален файл: only_guns/images/train/resized_P226_tacops.jpg
# Удален файл: only_guns/images/train/resized_1011133951_105.jpg
# Удален файл: only_guns/images/train/resized_1011133951_193.jpg
# Удален файл: only_guns/images/train/resized_armas (2755).jpg
# Удален файл: only_guns/images/train/resized_armas (2751).jpg
# Удален файл: only_guns/images/train/resized_armas (2771).jpg
# Удален файл: only_guns/images/train/resized_1011133951_139.jpg
# Удален файл: only_guns/images/train/resized_CZ85B.jpg
# Удален файл: only_guns/images/train/resized_armas (2759).jpg
# Удален файл: only_guns/images/train/resized_armas (2731).jpg
# Удален файл: only_guns/images/train/resized_armas (2741).jpg
# Удален файл: only_guns/images/train/resized_armas (2752).jpg
# Удален файл: only_guns/images/train/resized_00000330.jpg
# Удален файл: only_guns/images/train/resized_1011133951_297.jpg
# Удален файл: only_guns/images/train/resized_armas (2756).jpg
# Удален файл: only_guns/images/train/resized_1011133951_280.jpg
# Удален файл: only_guns/images/train/resized_1011133951_292.jpg
# Удален файл: only_guns/images/train/resized_armas (2735).jpg
# Удален файл: only_guns/images/train/resized_MP-654K.jpg
# Удален файл: only_guns/images/train/resized_1011133951_18.jpg
# Удален файл: only_guns/images/train/resized_HKmp5A_3.jpg
# Удален файл: only_guns/images/train/resized_1011133951_97.jpg
# Удален файл: only_guns/images/train/resized_armas (2763).jpg
# Удален файл: only_guns/images/train/resized_armas (2711).jpg
# Удален файл: only_guns/images/train/resized_Baby_browning.jpg
# Удален файл: only_guns/images/train/resized_armas (2749).jpg
# Удален файл: only_guns/images/train/resized_armas (2762).jpg
# Удален файл: only_guns/images/train/resized_armas (2705).jpg
# Удален файл: only_guns/images/train/resized_armas (2734).jpg
# Удален файл: only_guns/images/train/resized_Ekol_Aras_Compact.jpg
# Удален файл: only_guns/images/train/resized_1011133951_87.jpg
# Удален файл: only_guns/images/train/resized_Beretta_92FS_Inox_wood_grips.jpg
# Удален файл: only_guns/images/train/resized_1011133951_41.jpg
# Удален файл: only_guns/images/train/resized_armas (2766).jpg
# Удален файл: only_guns/images/train/resized_1011133950_177.jpg
# Удален файл: only_guns/images/train/resized_00000113.jpg
# Удален файл: only_guns/images/train/resized_1011133951_247.jpg
# Удален файл: only_guns/images/train/resized_armas (2721).jpg
# Удален файл: only_guns/images/train/resized_1011133951_186.jpg
# Удален файл: only_guns/images/train/resized_Taurus_pt_99.jpg
# Удален файл: only_guns/images/train/resized_1011133950_150.jpg
# Удален файл: only_guns/images/train/resized_armas (2716).jpg
# Удален файл: only_guns/images/train/resized_armas (2818).jpg
# Удален файл: only_guns/images/train/resized_1011133951_330.jpg
# Удален файл: only_guns/images/train/resized_armas (2737).jpg
# Удален файл: only_guns/images/train/resized_1011133951_242.jpg
# Удален файл: only_guns/images/train/resized_P250-TT-detail-R.jpg
# Удален файл: only_guns/images/train/resized_armas (2753).jpg
# Удален файл: only_guns/images/train/resized_1011133951_278.jpg
# Удален файл: only_guns/images/train/resized_1011133951_185.jpg
# Удален файл: only_guns/images/train/resized_Taurus_pt_100.jpg
# Удален файл: only_guns/images/train/resized_00000152.jpg
# Удален файл: only_guns/images/train/resized_1011133951_92.jpg
# Удален файл: only_guns/images/train/resized_armas (2747).jpg
# Удален файл: only_guns/images/train/resized_1011133951_170.jpg
# Удален файл: only_guns/images/train/resized_00000391.jpg
# Удален файл: only_guns/images/train/resized_armas (2969).jpg
# Удален файл: only_guns/images/train/resized_armas (2768).jpg
# Удален файл: only_guns/images/train/resized_Reck_cobra.jpg
# Удален файл: only_guns/images/train/resized_1011133951_244.jpg
# Удален файл: only_guns/images/train/resized_armas (2728).jpg
# Удален файл: only_guns/images/train/resized_Manufrance-Le_Francais_Pocket_Pistol.jpg
# Удален файл: only_guns/images/train/resized_RugerP_89.jpg
# Удален файл: only_guns/images/train/resized_1011133951_169.jpg
# Удален файл: only_guns/images/train/resized_1011133951_167.jpg
# Удален файл: only_guns/images/train/resized_Walther_P88C_2.jpg
# Удален файл: only_guns/images/train/resized_MonsterS&WModel_617.jpg
# Удален файл: only_guns/images/train/resized_1011133951_30.jpg
# Удален файл: only_guns/images/train/resized_Para_OrdnanceP-_10.jpg
# Удален файл: only_guns/images/train/resized_1011133950_117.jpg
# Удален файл: only_guns/images/train/resized_Mas_1950.jpg
# Удален файл: only_guns/images/train/resized_armas (2765).jpg
# Удален файл: only_guns/images/train/resized_armas (2775).jpg
# Удален файл: only_guns/images/train/resized_armas (2703).jpg
# Удален файл: only_guns/images/train/resized_1011133950_83.jpg
# Удален файл: only_guns/images/train/resized_1011133951_12.jpg
# Удален файл: only_guns/images/train/resized_armas (2814).jpg
# Удален файл: only_guns/images/train/resized_Unique_Rr-_51.jpg
# Удален файл: only_guns/images/train/resized_armas (2745).jpg
# Удален файл: only_guns/images/train/resized_00000211.jpg
# Удален файл: only_guns/images/train/resized_armas (2706).jpg
# Удален файл: only_guns/images/train/resized_P226_tactical.jpg
# Удален файл: only_guns/images/train/resized_Ruger_22_45_lite.jpg
# Удален файл: only_guns/images/train/resized_armas (2778).jpg
# Удален файл: only_guns/images/train/resized_1011133951_299.jpg
# Удален файл: only_guns/images/train/resized_Ots_27.jpg
# Удален файл: only_guns/images/train/resized_1011133951_172.jpg
# Удален файл: only_guns/images/train/resized_armas (2757).jpg
# Удален файл: only_guns/images/train/resized_1011133951_21.jpg
# Удален файл: only_guns/images/train/resized_armas (2708).jpg
# Удален файл: only_guns/images/train/resized_1011133951_324.jpg
# Удален файл: only_guns/images/train/resized_Cz_75.jpg
# Удален файл: only_guns/images/train/resized_1011133951_322.jpg
# Удален файл: only_guns/images/train/resized_Ber_950.jpg
# Удален файл: only_guns/images/train/resized_Kimar_Mod_75_Auto.jpg
# Удален файл: only_guns/images/train/resized_1011133951_131.jpg
# Удален файл: only_guns/images/train/resized_Usp_comp_tact.jpg
# Удален файл: only_guns/images/train/resized_armas (2772).jpg
# Удален файл: only_guns/images/train/resized_00000842.jpg
# Удален файл: only_guns/images/train/resized_1011133950_157.jpg
# Удален файл: only_guns/images/train/resized_00000768.jpg
# Удален файл: only_guns/images/train/resized_00001246.jpg
# Удален файл: only_guns/images/train/resized_Cz75com.jpg
# Удален файл: only_guns/images/train/resized_Manurhin_mr-_73.jpg
# Удален файл: only_guns/images/train/resized_BladeRunner1982Blaster_01.jpg
# Удален файл: only_guns/images/train/resized_armas (2925).jpg
# Удален файл: only_guns/images/train/resized_1011133951_207.jpg
# Удален файл: only_guns/images/train/resized_armas (2960).jpg
# Удален файл: only_guns/images/train/resized_1011133951_215.jpg
# Удален файл: only_guns/images/train/resized_1011133951_4.jpg
# Удален файл: only_guns/images/train/resized_1011133951_91.jpg
# Удален файл: only_guns/images/train/resized_Smith_wesson_60.jpg
# Удален файл: only_guns/images/train/resized_F88A1C.jpg
# Удален файл: only_guns/images/train/resized_1011133951_127.jpg
# Удален файл: only_guns/images/train/resized_Picture-350h.jpg
# Удален файл: only_guns/images/train/resized_1011133951_301.jpg
# Удален файл: only_guns/images/train/resized_1011133951_161.jpg
# Удален файл: only_guns/images/train/resized_Beretta8000CougarF.jpg
# Удален файл: only_guns/images/train/resized_armas (2702).jpg
# Удален файл: only_guns/images/train/resized_1011133951_332.jpg
# Удален файл: only_guns/images/train/resized_ParaBlackOps.jpg
# Удален файл: only_guns/images/train/resized_1011133951_115.jpg
# Удален файл: only_guns/images/train/resized_Unique_Kriegsmodell.jpg
# Удален файл: only_guns/images/train/resized_armas (2748).jpg
# Удален файл: only_guns/images/train/resized_1011133951_198.jpg
# Удален файл: only_guns/images/train/resized_TaurusPT92C.jpg
# Удален файл: only_guns/images/train/resized_44_elenco.jpg
# Удален файл: only_guns/images/train/resized_Glock_12892-1-.jpg
# Удален файл: only_guns/images/train/resized_Arminius_HW_10.jpg
# Удален файл: only_guns/images/train/resized_armas (2725).jpg
# Удален файл: only_guns/images/train/resized_1011133950_26.jpg
# Удален файл: only_guns/images/train/resized_00001047.jpg
# Удален файл: only_guns/images/train/resized_1011133951_319.jpg
# Удален файл: only_guns/images/train/resized_1011133951_254.jpg
# Удален файл: only_guns/images/train/resized_armas (2744).jpg
# Удален файл: only_guns/images/train/resized_00000271.jpg
# Удален файл: only_guns/images/train/resized_00001295.jpg
# Удален файл: only_guns/images/train/resized_1011133951_274.jpg
# Удален файл: only_guns/images/train/resized_Beretta_compact.jpg
# Удален файл: only_guns/images/train/resized_1011133951_124.jpg
# Удален файл: only_guns/images/train/resized_armas (2776).jpg
# Удален файл: only_guns/images/train/resized_armas (2730).jpg
# Удален файл: only_guns/images/train/resized_armas (2983).jpg
# Удален файл: only_guns/images/train/resized_USP45SS.jpg
# Удален файл: only_guns/images/train/resized_ThreeKingsT_5.jpg
# Удален файл: only_guns/images/train/resized_armas (2780).jpg
# Удален файл: only_guns/images/train/resized_00001073.jpg
# Очистка папки с метками...
# Очистка завершена!

# %%
import os
import yaml

# Функция для загрузки конфигурации из YAML-файла
def load_yaml_config(yaml_path):
    with open(yaml_path, 'r') as file:
        config = yaml.safe_load(file)
    return config

# Пути к папке only_guns
only_guns_dir = '/home/jovyan/work/yolo_train/filtred/only_guns'
images_train_dir = os.path.join(only_guns_dir, 'images', 'train')  # Папка с изображениями
labels_dir = os.path.join(only_guns_dir, 'labels')  # Папка с метками (без train)

# Загрузка конфигурации
yaml_path = '/home/jovyan/work/yolo_train/sort.yaml'  # Укажите путь к вашему YAML-файлу
config = load_yaml_config(yaml_path)

# Получение базового пути и путей для обучения
base_path = config['path']
train_image_paths = [os.path.join(base_path, path) for path in config['train_images']]
train_ann_paths = [os.path.join(base_path, path) for path in config['train_annotations']]

# Проверяем, существуют ли папки only_guns
if not os.path.exists(images_train_dir) or not os.path.exists(labels_dir):
    print(f"Папки {images_train_dir} или {labels_dir} не существуют. Убедитесь, что они созданы.")
    exit(1)

# Получаем список всех изображений и меток в only_guns
copied_images = set(os.listdir(images_train_dir))
copied_labels = set(os.listdir(labels_dir))

# Удаляем изображения и метки из исходных папок, если они были скопированы в only_guns
for images_source_dir, labels_source_dir in zip(train_image_paths, train_ann_paths):
    print(f"Обработка папки: {images_source_dir} и {labels_source_dir}")

    # Убедимся, что исходные папки существуют
    if not os.path.exists(images_source_dir) or not os.path.exists(labels_source_dir):
        print(f"Папки {images_source_dir} или {labels_source_dir} не существуют. Пропускаем.")
        continue

    # Удаляем изображения из исходной папки
    print("Удаление изображений из исходной папки...")
    for img_name in copied_images:
        img_path = os.path.join(images_source_dir, img_name)
        if os.path.exists(img_path):
            try:
                os.remove(img_path)
                print(f"Удалено изображение: {img_path}")
            except Exception as e:
                print(f"Ошибка при удалении изображения {img_path}: {e}")
        else:
            print(f"Изображение {img_path} не найдено в исходной папке. Пропускаем.")

    # Удаляем метки из исходной папки
    print("Удаление меток из исходной папки...")
    for lbl_name in copied_labels:
        lbl_path = os.path.join(labels_source_dir, lbl_name)
        if os.path.exists(lbl_path):
            try:
                os.remove(lbl_path)
                print(f"Удалена метка: {lbl_path}")
            except Exception as e:
                print(f"Ошибка при удалении метки {lbl_path}: {e}")
        else:
            print(f"Метка {lbl_path} не найдена в исходной папке. Пропускам.")

print("Очистка завершена!")
# Out:
# Обработка папки: /home/jovyan/work/yolo_train/filtred/div/images и /home/jovyan/work/yolo_train/filtred/div/labels
# Удаление изображений из исходной папки...
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_115.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2775).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/BladeRunner1982Blaster_01.jpg
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/LorcinL_380.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2702).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/F88A1C.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2729).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_263.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/HK_P_30.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2746).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2705).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2741).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2951).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/ArminiusC.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00001047.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000330.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2739).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Para_OrdnanceP-_10.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2733).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/LiliputPistol.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/44_elenco.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2747).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Taurus_911.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_149.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2825).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2716).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2735).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Brixia_92.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2715).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2713).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2718).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Ruger_22_45_lite.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2701).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2703).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1851USMarshall.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2725).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2772).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/P226_tacops.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2730).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2814).jpg не найдено в исходной папке. Пропускаем.
# Ошибка при удалении изображения /home/jovyan/work/yolo_train/filtred/div/images/.ipynb_checkpoints: [Errno 21] Is a directory: '/home/jovyan/work/yolo_train/filtred/div/images/.ipynb_checkpoints'
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_324.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_285.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2766).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2768).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2773).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2777).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Tec-38Derringer.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2727).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Beretta92oldest.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_87.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2771).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2763).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Taurus_pt_100.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_297.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Arcus_98.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2877).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/USP45SS.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_236.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Ng_pistol_beretta92_SN.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000543.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Bulldog_Hammerless.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_97.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/ThreeKingsT_5.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2734).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00001246.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/P226r-dak-large.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_83.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_131.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_100.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/ParaBlackOps.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Unique_Kriegsmodell.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Beretta_92FS_Inox_wood_grips.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/P250-TT-detail-R.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2726).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000311.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2748).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2751).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Beretta8000CougarF.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000098.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2737).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2706).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Baby_browning.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Mas_1950.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_26.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000284.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2710).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Ber_950.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2960).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2757).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Cz75com.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2711).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2778).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Smith_wesson_60.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000790.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_254.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000768.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2925).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2720).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2708).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_62.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2712).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2780).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_205.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/EKOL_Spec_Silver.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Sauer38H.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2709).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00001073.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/HK_P30L.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_95.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Intratec_TEC-_22.jpg
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/SIG-Sauer_P229_E_2.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Manufrance-Le_Francais_Pocket_Pistol.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_139.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2818).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_21.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2745).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/P226_tactical.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/HKmp5A_3.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2740).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_198.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2752).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/MP-654K.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Arminius_HW_10.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2770).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/TaurusPT92C.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_215.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2969).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000211.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Em-Ge_Model_5.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Reck_cobra.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000942.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/CZ85B.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2742).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2756).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Picture-350h.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2759).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_286.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00001295.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2983).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2721).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2765).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_274.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_117.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2732).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Beretta_compact.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2774).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2755).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000533.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2723).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2761).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2749).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2707).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Glock_12892-1-.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Walther_P88C_2.jpg
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Taurus_pt_99.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Maxsell_Beretta_85_Replica.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Usp_comp_tact.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Kimar_Mod_75_Auto.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Manurhin_mr-_73.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2728).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_59.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2731).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000782.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2762).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2744).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Ekol_Aras_Compact.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_180.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000113.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2753).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2760).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2743).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_292.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_280.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Llama-Model-II.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2776).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2750).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Unique_Rr-_51.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2738).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/RugerP_89.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/8mm_sig_sauer_prop.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Cz_75.jpg
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Intratec_Cat_9.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000152.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_186.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/MonsterS&WModel_617.jpg
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/div/images/Ots_27.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2758).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2736).jpg не найдено в исходной папке. Пропускаем.
# Удаление меток из исходной папки...
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2733).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2983).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000330.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000311.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2727).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2751).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Usp_comp_tact.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Beretta_92FS_Inox_wood_grips.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Baby_browning.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2753).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000211.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/SIG-Sauer_P229_E_2.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Ber_950.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1851USMarshall.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000098.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2877).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2715).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2759).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2741).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2713).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2716).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2778).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Ng_pistol_beretta92_SN.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2774).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_205.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2969).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_285.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_59.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00001073.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2737).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Tec-38Derringer.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Manurhin_mr-_73.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_100.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2763).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2772).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2721).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2711).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2766).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_62.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000533.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/LorcinL_380.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2703).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000782.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/P226_tactical.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2749).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2761).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Ots_27.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_297.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2770).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2776).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2748).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2730).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_324.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Beretta8000CougarF.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2742).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Picture-350h.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/.ipynb_checkpoints не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/EKOL_Spec_Silver.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2755).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Em-Ge_Model_5.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2732).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2740).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Cz75com.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/P226r-dak-large.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_236.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2707).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2744).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2734).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_95.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Sauer38H.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000543.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2725).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Ruger_22_45_lite.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_21.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2709).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00001246.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2735).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Arcus_98.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/P250-TT-detail-R.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/F88A1C.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2708).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Bulldog_Hammerless.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2736).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Unique_Rr-_51.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2723).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Ekol_Aras_Compact.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2731).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2710).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2701).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Smith_wesson_60.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_215.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000790.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/CZ85B.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2758).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/LiliputPistol.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2773).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_115.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2951).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_117.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/TaurusPT92C.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/HKmp5A_3.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2743).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000284.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_149.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00001295.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/44_elenco.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Brixia_92.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2705).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/HK_P_30.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/P226_tacops.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Intratec_Cat_9.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Arminius_HW_10.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_286.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2718).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/USP45SS.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/ArminiusC.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_254.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_263.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/MP-654K.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2760).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2750).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2752).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Beretta_compact.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/ParaBlackOps.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_139.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_280.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2757).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2746).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Reck_cobra.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Glock_12892-1-.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Para_OrdnanceP-_10.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Beretta92oldest.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_198.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_131.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Llama-Model-II.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_83.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2720).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000113.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2756).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2745).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Taurus_911.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2818).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2925).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/ThreeKingsT_5.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Manufrance-Le_Francais_Pocket_Pistol.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2775).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2765).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2771).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2768).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/HK_P30L.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/8mm_sig_sauer_prop.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Kimar_Mod_75_Auto.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000152.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/BladeRunner1982Blaster_01.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000768.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/MonsterS&WModel_617.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_97.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2747).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00001047.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2762).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2738).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000942.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2726).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Mas_1950.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/RugerP_89.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Unique_Kriegsmodell.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2814).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2729).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2728).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_180.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Cz_75.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_87.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2712).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2777).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2706).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2780).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_292.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Intratec_TEC-_22.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Taurus_pt_100.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2739).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2702).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_26.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_274.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2960).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Walther_P88C_2.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Maxsell_Beretta_85_Replica.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2825).txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/div/labels/Taurus_pt_99.txt
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_186.txt не найдена в исходной папке. Пропускам.
# Обработка папки: /home/jovyan/work/yolo_train/filtred/vids/images и /home/jovyan/work/yolo_train/filtred/vids/labels
# Удаление изображений из исходной папки...
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/vids/images/1011133951_115.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2775).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/BladeRunner1982Blaster_01.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/LorcinL_380.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2702).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/F88A1C.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2729).jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/vids/images/1011133951_263.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/HK_P_30.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2746).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2705).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2741).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2951).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/ArminiusC.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/00001047.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/00000330.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2739).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/Para_OrdnanceP-_10.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2733).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/LiliputPistol.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/44_elenco.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2747).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/Taurus_911.jpg не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/vids/images/1011133951_149.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2825).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2716).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2735).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/Brixia_92.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2715).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2713).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2718).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/Ruger_22_45_lite.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2701).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2703).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/1851USMarshall.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2725).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2772).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/P226_tacops.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2730).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2814).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/.ipynb_checkpoints не найдено в исходной папке. Пропускаем.
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/vids/images/1011133951_324.jpg
# Удалено изображение: /home/jovyan/work/yolo_train/filtred/vids/images/1011133951_285.jpg
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2766).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2768).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2773).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2777).jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/Tec-38Derringer.jpg не найдено в исходной папке. Пропускаем.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2727).jpg не найдено в исходной папке. Пропускаем.
# ...
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2715).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2759).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2741).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2713).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2716).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2778).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Ng_pistol_beretta92_SN.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2774).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_205.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2969).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_285.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_59.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00001073.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2737).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Tec-38Derringer.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Manurhin_mr-_73.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133950_100.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2763).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2772).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2721).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2711).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2766).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_62.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00000533.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/LorcinL_380.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2703).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00000782.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/P226_tactical.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2749).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2761).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Ots_27.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_297.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2770).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2776).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2748).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2730).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_324.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Beretta8000CougarF.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2742).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Picture-350h.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/.ipynb_checkpoints не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/EKOL_Spec_Silver.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2755).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Em-Ge_Model_5.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2732).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2740).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Cz75com.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/P226r-dak-large.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_236.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2707).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2744).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2734).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_95.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Sauer38H.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00000543.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2725).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Ruger_22_45_lite.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_21.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2709).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00001246.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2735).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Arcus_98.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/P250-TT-detail-R.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/F88A1C.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2708).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Bulldog_Hammerless.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2736).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Unique_Rr-_51.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2723).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Ekol_Aras_Compact.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2731).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2710).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2701).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Smith_wesson_60.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_215.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00000790.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/CZ85B.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2758).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/LiliputPistol.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2773).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_115.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2951).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133950_117.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/TaurusPT92C.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/HKmp5A_3.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2743).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00000284.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_149.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00001295.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/44_elenco.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Brixia_92.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2705).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/HK_P_30.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/P226_tacops.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Intratec_Cat_9.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Arminius_HW_10.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_286.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2718).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/USP45SS.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/ArminiusC.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_254.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_263.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/MP-654K.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2760).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2750).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2752).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Beretta_compact.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/ParaBlackOps.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_139.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_280.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2757).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2746).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Reck_cobra.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Glock_12892-1-.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Para_OrdnanceP-_10.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Beretta92oldest.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_198.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_131.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Llama-Model-II.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133950_83.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2720).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00000113.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2756).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2745).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Taurus_911.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2818).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2925).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/ThreeKingsT_5.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Manufrance-Le_Francais_Pocket_Pistol.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2775).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2765).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2771).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2768).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/HK_P30L.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/8mm_sig_sauer_prop.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Kimar_Mod_75_Auto.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00000152.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/BladeRunner1982Blaster_01.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00000768.txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/MonsterS&WModel_617.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_97.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2747).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00001047.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2762).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2738).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/00000942.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2726).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Mas_1950.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/RugerP_89.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Unique_Kriegsmodell.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2814).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2729).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2728).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133950_180.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Cz_75.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_87.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2712).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2777).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2706).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2780).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_292.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Intratec_TEC-_22.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Taurus_pt_100.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2739).txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2702).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133950_26.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_274.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2960).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Walther_P88C_2.txt не найдена в исходной папке. Пропускам.
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/Maxsell_Beretta_85_Replica.txt
# Удалена метка: /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2825).txt
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Taurus_pt_99.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_186.txt не найдена в исходной папке. Пропускам.
# Очистка завершена!

# %%
import os
import yaml

# Функция для загрузки конфигурации из YAML-файла
def load_yaml_config(yaml_path):
    with open(yaml_path, 'r') as file:
        config = yaml.safe_load(file)
    return config

# Пути к папке only_guns
only_guns_dir = '/home/jovyan/work/yolo_train/filtred/only_guns'
images_train_dir = os.path.join(only_guns_dir, 'images', 'train')  # Папка с изображениями
labels_dir = os.path.join(only_guns_dir, 'labels')  # Папка с метками (без train)

# Загрузка конфигурации
yaml_path = '/home/jovyan/work/yolo_train/sort.yaml'  # Укажите путь к вашему YAML-файлу
config = load_yaml_config(yaml_path)

# Получение базового пути и путей для обучения
base_path = config['path']
train_image_paths = [os.path.join(base_path, path) for path in config['train_images']]
train_ann_paths = [os.path.join(base_path, path) for path in config['train_annotations']]

# Проверяем, существуют ли папки only_guns
if not os.path.exists(images_train_dir) or not os.path.exists(labels_dir):
    print(f"Папки {images_train_dir} или {labels_dir} не существуют. Убедитесь, что они созданы.")
    exit(1)

# Получаем список всех изображений и меток в only_guns
copied_images = set(os.listdir(images_train_dir))
copied_labels = set(os.listdir(labels_dir))

# Счетчики для удаленных файлов
deleted_images_count = 0
deleted_labels_count = 0

# Удаляем изображения и метки из исходных папок, если они были скопированы в only_guns
for images_source_dir, labels_source_dir in zip(train_image_paths, train_ann_paths):
    print(f"Обработка папки: {images_source_dir} и {labels_source_dir}")

    # Убедимся, что исходные папки существуют
    if not os.path.exists(images_source_dir) or not os.path.exists(labels_source_dir):
        print(f"Папки {images_source_dir} или {labels_source_dir} не существуют. Пропускаем.")
        continue

    # Удаляем изображения из исходной папки
    print("Удаление изображений из исходной папки...")
    for img_name in copied_images:
        img_path = os.path.join(images_source_dir, img_name)
        if os.path.exists(img_path):
            try:
                os.remove(img_path)
                print(f"Удалено изображение: {img_path}")
                deleted_images_count += 1  # Увеличиваем счетчик удаленных изображений
            except Exception as e:
                print(f"Ошибка при удалении изображения {img_path}: {e}")
        else:
            print(f"Изображение {img_path} не найдено в исходной папке. Пропускам.")

    # Удаляем метки из исходной папки
    print("Удаление меток из исходной папки...")
    for lbl_name in copied_labels:
        lbl_path = os.path.join(labels_source_dir, lbl_name)
        if os.path.exists(lbl_path):
            try:
                os.remove(lbl_path)
                print(f"Удалена метка: {lbl_path}")
                deleted_labels_count += 1  # Увеличиваем счетчик удаленных меток
            except Exception as e:
                print(f"Ошибка при удалении метки {lbl_path}: {e}")
        else:
            print(f"Метка {lbl_path} не найдена в исходной папке. Пропускам.")

# Выводим итоговую статистику
print(f"Всего удалено изображений: {deleted_images_count}")
print(f"Всего удалено меток: {deleted_labels_count}")
print("Очистка завершена!")
# Out:
# Обработка папки: /home/jovyan/work/yolo_train/filtred/div/images и /home/jovyan/work/yolo_train/filtred/div/labels
# Удаление изображений из исходной папки...
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_115.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2775).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/BladeRunner1982Blaster_01.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/LorcinL_380.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2702).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/F88A1C.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2729).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_263.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/HK_P_30.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2746).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2705).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2741).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2951).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/ArminiusC.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00001047.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000330.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2739).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Para_OrdnanceP-_10.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2733).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/LiliputPistol.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/44_elenco.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2747).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Taurus_911.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_149.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2825).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2716).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2735).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Brixia_92.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2715).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2713).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2718).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Ruger_22_45_lite.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2701).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2703).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1851USMarshall.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2725).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2772).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/P226_tacops.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2730).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2814).jpg не найдено в исходной папке. Пропускам.
# Ошибка при удалении изображения /home/jovyan/work/yolo_train/filtred/div/images/.ipynb_checkpoints: [Errno 21] Is a directory: '/home/jovyan/work/yolo_train/filtred/div/images/.ipynb_checkpoints'
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_324.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_285.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2766).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2768).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2773).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2777).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Tec-38Derringer.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2727).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Beretta92oldest.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_87.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2771).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2763).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Taurus_pt_100.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_297.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Arcus_98.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2877).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/USP45SS.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_236.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Ng_pistol_beretta92_SN.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000543.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Bulldog_Hammerless.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_97.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/ThreeKingsT_5.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2734).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00001246.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/P226r-dak-large.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_83.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_131.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_100.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/ParaBlackOps.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Unique_Kriegsmodell.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Beretta_92FS_Inox_wood_grips.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/P250-TT-detail-R.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2726).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000311.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2748).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2751).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Beretta8000CougarF.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000098.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2737).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2706).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Baby_browning.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Mas_1950.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_26.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000284.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2710).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Ber_950.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2960).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2757).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Cz75com.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2711).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2778).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Smith_wesson_60.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000790.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_254.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000768.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2925).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2720).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2708).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_62.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2712).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2780).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_205.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/EKOL_Spec_Silver.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Sauer38H.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2709).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00001073.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/HK_P30L.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_95.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Intratec_TEC-_22.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/SIG-Sauer_P229_E_2.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Manufrance-Le_Francais_Pocket_Pistol.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_139.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2818).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_21.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2745).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/P226_tactical.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/HKmp5A_3.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2740).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_198.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2752).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/MP-654K.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Arminius_HW_10.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2770).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/TaurusPT92C.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_215.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2969).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000211.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Em-Ge_Model_5.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Reck_cobra.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000942.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/CZ85B.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2742).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2756).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Picture-350h.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2759).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_286.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00001295.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2983).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2721).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2765).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_274.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_117.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2732).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Beretta_compact.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2774).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2755).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000533.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2723).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2761).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2749).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2707).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Glock_12892-1-.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Walther_P88C_2.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Taurus_pt_99.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Maxsell_Beretta_85_Replica.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Usp_comp_tact.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Kimar_Mod_75_Auto.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Manurhin_mr-_73.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2728).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_59.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2731).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000782.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2762).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2744).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Ekol_Aras_Compact.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133950_180.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000113.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2753).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2760).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2743).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_292.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_280.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Llama-Model-II.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2776).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2750).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Unique_Rr-_51.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2738).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/RugerP_89.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/8mm_sig_sauer_prop.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Cz_75.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Intratec_Cat_9.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/00000152.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/1011133951_186.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/MonsterS&WModel_617.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/Ots_27.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2758).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/div/images/armas (2736).jpg не найдено в исходной папке. Пропускам.
# Удаление меток из исходной папки...
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2733).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2983).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000330.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000311.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2727).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2751).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Usp_comp_tact.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Beretta_92FS_Inox_wood_grips.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Baby_browning.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2753).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000211.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/SIG-Sauer_P229_E_2.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Ber_950.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1851USMarshall.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000098.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2877).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2715).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2759).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2741).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2713).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2716).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2778).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Ng_pistol_beretta92_SN.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2774).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_205.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2969).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_285.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_59.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00001073.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2737).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Tec-38Derringer.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Manurhin_mr-_73.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_100.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2763).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2772).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2721).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2711).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2766).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_62.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000533.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/LorcinL_380.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2703).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000782.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/P226_tactical.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2749).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2761).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Ots_27.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_297.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2770).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2776).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2748).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2730).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_324.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Beretta8000CougarF.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2742).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Picture-350h.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/.ipynb_checkpoints не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/EKOL_Spec_Silver.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2755).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Em-Ge_Model_5.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2732).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2740).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Cz75com.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/P226r-dak-large.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_236.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2707).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2744).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2734).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_95.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Sauer38H.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000543.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2725).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Ruger_22_45_lite.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_21.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2709).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00001246.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2735).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Arcus_98.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/P250-TT-detail-R.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/F88A1C.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2708).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Bulldog_Hammerless.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2736).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Unique_Rr-_51.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2723).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Ekol_Aras_Compact.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2731).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2710).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2701).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Smith_wesson_60.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_215.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000790.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/CZ85B.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2758).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/LiliputPistol.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2773).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_115.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2951).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_117.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/TaurusPT92C.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/HKmp5A_3.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2743).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000284.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_149.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00001295.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/44_elenco.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Brixia_92.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2705).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/HK_P_30.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/P226_tacops.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Intratec_Cat_9.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Arminius_HW_10.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_286.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2718).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/USP45SS.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/ArminiusC.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_254.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_263.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/MP-654K.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2760).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2750).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2752).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Beretta_compact.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/ParaBlackOps.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_139.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_280.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2757).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2746).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Reck_cobra.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Glock_12892-1-.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Para_OrdnanceP-_10.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Beretta92oldest.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_198.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_131.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Llama-Model-II.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_83.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2720).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000113.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2756).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2745).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Taurus_911.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2818).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2925).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/ThreeKingsT_5.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Manufrance-Le_Francais_Pocket_Pistol.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2775).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2765).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2771).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2768).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/HK_P30L.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/8mm_sig_sauer_prop.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Kimar_Mod_75_Auto.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000152.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/BladeRunner1982Blaster_01.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000768.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/MonsterS&WModel_617.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_97.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2747).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00001047.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2762).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2738).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/00000942.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2726).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Mas_1950.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/RugerP_89.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Unique_Kriegsmodell.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2814).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2729).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2728).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_180.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Cz_75.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_87.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2712).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2777).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2706).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2780).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_292.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Intratec_TEC-_22.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Taurus_pt_100.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2739).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2702).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133950_26.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_274.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2960).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Walther_P88C_2.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Maxsell_Beretta_85_Replica.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/armas (2825).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/Taurus_pt_99.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/div/labels/1011133951_186.txt не найдена в исходной папке. Пропускам.
# Обработка папки: /home/jovyan/work/yolo_train/filtred/vids/images и /home/jovyan/work/yolo_train/filtred/vids/labels
# Удаление изображений из исходной папки...
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/1011133951_115.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2775).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/BladeRunner1982Blaster_01.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/LorcinL_380.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2702).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/F88A1C.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2729).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/1011133951_263.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/HK_P_30.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2746).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2705).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2741).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2951).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/ArminiusC.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/00001047.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/00000330.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2739).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/Para_OrdnanceP-_10.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2733).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/LiliputPistol.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/44_elenco.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2747).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/Taurus_911.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/1011133951_149.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2825).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2716).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2735).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/Brixia_92.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2715).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2713).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2718).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/Ruger_22_45_lite.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2701).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2703).jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/1851USMarshall.jpg не найдено в исходной папке. Пропускам.
# Изображение /home/jovyan/work/yolo_train/filtred/vids/images/armas (2725).jpg не найдено в исходной папке. Пропускам.
# ...
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2776).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2748).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2730).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_324.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Beretta8000CougarF.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2742).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Picture-350h.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/.ipynb_checkpoints не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/EKOL_Spec_Silver.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2755).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Em-Ge_Model_5.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2732).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2740).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Cz75com.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/P226r-dak-large.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_236.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2707).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2744).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2734).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_95.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Sauer38H.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00000543.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2725).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Ruger_22_45_lite.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_21.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2709).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00001246.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2735).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Arcus_98.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/P250-TT-detail-R.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/F88A1C.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2708).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Bulldog_Hammerless.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2736).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Unique_Rr-_51.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2723).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Ekol_Aras_Compact.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2731).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2710).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2701).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Smith_wesson_60.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_215.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00000790.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/CZ85B.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2758).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/LiliputPistol.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2773).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_115.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2951).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133950_117.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/TaurusPT92C.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/HKmp5A_3.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2743).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00000284.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_149.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00001295.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/44_elenco.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Brixia_92.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2705).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/HK_P_30.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/P226_tacops.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Intratec_Cat_9.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Arminius_HW_10.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_286.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2718).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/USP45SS.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/ArminiusC.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_254.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_263.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/MP-654K.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2760).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2750).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2752).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Beretta_compact.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/ParaBlackOps.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_139.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_280.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2757).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2746).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Reck_cobra.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Glock_12892-1-.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Para_OrdnanceP-_10.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Beretta92oldest.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_198.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_131.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Llama-Model-II.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133950_83.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2720).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00000113.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2756).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2745).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Taurus_911.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2818).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2925).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/ThreeKingsT_5.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Manufrance-Le_Francais_Pocket_Pistol.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2775).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2765).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2771).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2768).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/HK_P30L.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/8mm_sig_sauer_prop.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Kimar_Mod_75_Auto.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00000152.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/BladeRunner1982Blaster_01.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00000768.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/MonsterS&WModel_617.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_97.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2747).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00001047.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2762).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2738).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/00000942.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2726).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Mas_1950.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/RugerP_89.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Unique_Kriegsmodell.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2814).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2729).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2728).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133950_180.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Cz_75.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_87.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2712).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2777).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2706).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2780).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_292.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Intratec_TEC-_22.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Taurus_pt_100.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2739).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2702).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133950_26.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_274.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2960).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Walther_P88C_2.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Maxsell_Beretta_85_Replica.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/armas (2825).txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/Taurus_pt_99.txt не найдена в исходной папке. Пропускам.
# Метка /home/jovyan/work/yolo_train/filtred/mixed/labels/1011133951_186.txt не найдена в исходной папке. Пропускам.
# Всего удалено изображений: 0
# Всего удалено меток: 0
# Очистка завершена!
